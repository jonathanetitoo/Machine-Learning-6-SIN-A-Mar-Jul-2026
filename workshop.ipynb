# %%
# !curl -LsSf https://astral.sh/uv/install.sh | sh
# Out:
# downloading uv 0.11.1 x86_64-unknown-linux-gnu
# installing to /home/codespace/.local/bin
#   uv
#   uvx
# everything's installed!

# %%
# !uv self update
# Out:
# info: Checking for updates...
# success: You're already on version v0.11.1 of uv (the latest version).

# %% [markdown]
# # Create Virtual Enviaroment
#
# uv venv env
# source venv/bin/activate
# uv pip install ipykernel
# python -m ipykernel install --user --name=env

# %% [markdown]
# # Install Nympy and Pandas
# !uv pip install numpy
# !uv pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
date = pd.date_range("20260102", periods=6)
date
# Out:
# DatetimeIndex(['2026-01-02', '2026-01-03', '2026-01-04', '2026-01-05',
#                '2026-01-06', '2026-01-07'],
#               dtype='datetime64[us]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=date, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2026-01-02  0.306697  0.151837 -0.451024  1.103154
# 2026-01-03  0.033978 -0.417234 -0.126635 -1.331658
# 2026-01-04  0.869779 -2.985150 -1.587881 -0.608282
# 2026-01-05 -0.607605 -1.972759 -0.311969  0.534577
# 2026-01-06  1.160933  0.627102 -1.052148  0.560933
# 2026-01-07 -0.229629  0.007714  0.121934  0.305740
